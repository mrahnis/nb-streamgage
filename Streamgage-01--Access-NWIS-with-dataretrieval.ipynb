# %% [markdown]
# # Access NWIS with the USGS dataretrieval package

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mrahnis/nb-streamgage/blob/main/Streamgage-01--Access-NWIS-with-dataretrieval.ipynb)

# %% [markdown]
# ## The USGS dataretrieval package
#
# This package allows users to retrieve data using the USGS NWIS API. It is possible to get longer timeseries than is possible from the NWIS webpage. The dataretrieval git repository is here: https://github.com/USGS-python/dataretrieval

# %% [markdown]
# ## Setup and imports

# %%
# if using the regular Colab runtime install dataretrieval and ipyleaflet
# !pip install dataretrieval --quiet --exists-action i
# !pip install ipyleaflet --quiet --exists-action i

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataretrieval import nwis, wqp
from ipywidgets import HTML
from ipyleaflet import AwesomeIcon, Map, Marker, Popup, basemaps, basemap_to_tiles

# %%
favorites = {'01576516':'east branch',
            '015765185':'west branch',
            '015765195':'mainstem',
            '01576521':'mainstem-historical',
            '01576754':'conenstoga river at conestoga, pa'}

# %% [markdown]
# ## Get the USGS sites in Lancaster County

# %%
COUNTY_FIPS = 'US:42:071' # 'US:24:031' #
sites, _ = wqp.what_sites(countycode=COUNTY_FIPS, siteType='Stream')
sites
# Out:
#     OrganizationIdentifier                        OrganizationFormalName  \
# 0                  USGS-PA        USGS Pennsylvania Water Science Center
# 1                  USGS-PA        USGS Pennsylvania Water Science Center
# 2                  USGS-PA        USGS Pennsylvania Water Science Center
# 3                  USGS-PA        USGS Pennsylvania Water Science Center
# 4                  USGS-PA        USGS Pennsylvania Water Science Center
# ..                     ...                                           ...
# 712               MDE_TMDL            TMDL Technical Development Program
# 713                   NARS     EPA National Aquatic Resource Survey Data
# 714               NARSTEST  EPA National Aquatic Resources Survey (NARS)
# 715               NARS_WQX  EPA National Aquatic Resources Survey (NARS)
# 716               NARS_WQX  EPA National Aquatic Resources Survey (NARS)
#
#     MonitoringLocationIdentifier                      MonitoringLocationName  \
# 0                  USGS-01573700              Conewago Creek at Bellaire, PA
# 1                  USGS-01574050               Snitz Creek near Falmouth, PA
# 2                  USGS-01574055             Snitz Creek near Bainbridge, PA
# 3                  USGS-01574200            Conoy Creek at Elizabethtown, PA
# 4                  USGS-01574300  Conoy Creek Tributary at Elizabethtown, PA
# ..                           ...                                         ...
# 712             MDE_TMDL-SUS0160                                        CP-4
# 713           NARS-OWW04440-0242                          Meetinghouse Creek
# 714           NARSTEST-FW08PA018      Tributary to West Branch Ontario Creek
# 715           NARS_WQX-FW08PA018      Tributary to West Branch Ontario Creek
# 716       NARS_WQX-OWW04440-0242                          MEETINGHOUSE CREEK
#
#     MonitoringLocationTypeName  \
# 0                       Stream
# 1                       Stream
# 2                       Stream
# 3                       Stream
# 4                       Stream
# ..                         ...
# 712               River/Stream
# 713               River/Stream
# 714               River/Stream
# 715               River/Stream
# 716               River/Stream
#
#                      MonitoringLocationDescriptionText  HUCEightDigitCode  \
# 0                                                  NaN            2050305
# 1                                                  NaN            2050306
# 2                                                  NaN            2050306
# 3                                                  NaN            2050306
# 4                                                  NaN            2050306
# ..                                                 ...                ...
# 712                                                NaN            2050306
# 713  SITE TYPE is EASTPROB/Strahler Stream Order is...            2050306
# 714  FW_ECO3="EHIGH";URBAN="NonUrban";STRAHLERORDER...            2050306
# 715                                           NonUrban            2050306
# 716  XLON_DD="-76.898";XLAT_DD="39.9266";STRAHLER="...            2050306
#
#      DrainageAreaMeasure/MeasureValue DrainageAreaMeasure/MeasureUnitCode  \
# 0                               20.80                               sq mi
# 1                                0.23                               sq mi
# 2                                2.02                               sq mi
# 3                                3.02                               sq mi
# 4                                1.34                               sq mi
# ..                                ...                                 ...
# 712                               NaN                                 NaN
# 713                               NaN                                 NaN
# 714                               NaN                                 NaN
# 715                               NaN                                 NaN
# 716                               NaN                                 NaN
#
#      ContributingDrainageAreaMeasure/MeasureValue  ... AquiferName  \
# 0                                             NaN  ...         NaN
# 1                                             NaN  ...         NaN
# 2                                             NaN  ...         NaN
# 3                                             NaN  ...         NaN
# 4                                             NaN  ...         NaN
# ..                                            ...  ...         ...
# 712                                           NaN  ...         NaN
# 713                                           NaN  ...         NaN
# 714                                           NaN  ...         NaN
# 715                                           NaN  ...         NaN
# 716                                           NaN  ...         NaN
#
#      LocalAqfrName  FormationTypeText  AquiferTypeName ConstructionDateText  \
# 0              NaN                NaN              NaN                  NaN
# 1              NaN                NaN              NaN                  NaN
# 2              NaN                NaN              NaN                  NaN
# 3              NaN                NaN              NaN                  NaN
# 4              NaN                NaN              NaN                  NaN
# ..             ...                ...              ...                  ...
# 712            NaN                NaN              NaN                  NaN
# 713            NaN                NaN              NaN                  NaN
# 714            NaN                NaN              NaN                  NaN
# 715            NaN                NaN              NaN                  NaN
# 716            NaN                NaN              NaN                  NaN
#
#     WellDepthMeasure/MeasureValue WellDepthMeasure/MeasureUnitCode  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# ..                            ...                              ...
# 712                           NaN                              NaN
# 713                           NaN                              NaN
# 714                           NaN                              NaN
# 715                           NaN                              NaN
# 716                           NaN                              NaN
#
#     WellHoleDepthMeasure/MeasureValue  WellHoleDepthMeasure/MeasureUnitCode  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
# ..                                ...                                   ...
# 712                               NaN                                   NaN
# 713                               NaN                                   NaN
# 714                               NaN                                   NaN
# 715                               NaN                                   NaN
# 716                               NaN                                   NaN
#
#     ProviderName
# 0           NWIS
# 1           NWIS
# 2           NWIS
# 3           NWIS
# 4           NWIS
# ..           ...
# 712       STORET
# 713       STORET
# 714       STORET
# 715       STORET
# 716       STORET
#
# [717 rows x 37 columns]

# %%
# make a list of USGS site_no and then get site info for these
site_ids = sites[sites['ProviderName']=='NWIS']['MonitoringLocationIdentifier'].str[5:].to_list()
site_info, _ = nwis.get_info(sites=site_ids)
site_info.head()
# Out:
#   agency_cd   site_no                                  station_nm site_tp_cd  \
# 0      USGS  01573700              Conewago Creek at Bellaire, PA         ST
# 1      USGS  01574050               Snitz Creek near Falmouth, PA         ST
# 2      USGS  01574055             Snitz Creek near Bainbridge, PA         ST
# 3      USGS  01574200            Conoy Creek at Elizabethtown, PA         ST
# 4      USGS  01574300  Conoy Creek Tributary at Elizabethtown, PA         ST
#
#      lat_va   long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  \
# 0  401139.0  763437.0   40.194260   -76.576635             M            U
# 1  400802.6  763917.0   40.134056   -76.654722             G            S
# 2  400728.4  763952.4   40.124556   -76.664556             G            S
# 3  400909.0  763625.0   40.152594   -76.606634             M            U
# 4  400920.0  763655.0   40.155650   -76.614968             M            U
#
#    ... local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd  \
# 0  ...             Y            NaN    NNNNNNNN          NaN      NaN
# 1  ...             Y            NaN         NaN          NaN      NaN
# 2  ...             Y            NaN         NaN          NaN      NaN
# 3  ...             Y            NaN    NNNNNNNN          NaN      NaN
# 4  ...             Y            NaN    NNNNNNNN          NaN      NaN
#
#   aqfr_type_cd well_depth_va hole_depth_va  depth_src_cd  project_no
# 0          NaN           NaN           NaN           NaN         NaN
# 1          NaN           NaN           NaN           NaN   2476CDH00
# 2          NaN           NaN           NaN           NaN   2476CDH00
# 3          NaN           NaN           NaN           NaN         NaN
# 4          NaN           NaN           NaN           NaN         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Map the sites

# %%
# map the stations in Lancaster County, PA
center = (
    (site_info['dec_lat_va'].min() + site_info['dec_long_va'].max())/2,
    (site_info['dec_lat_va'].min() + site_info['dec_long_va'].max())/2,
)

m = Map(
    basemap=basemap_to_tiles(basemaps.OpenStreetMap.Mapnik),
    center=center,
    zoom=9
)

default_icon = AwesomeIcon(
    name='map-marker',
    marker_color='blue',
    icon_color='black',
    spin=False
)

favorite_icon = AwesomeIcon(
    name='map-marker',
    marker_color='red',
    icon_color='black',
    spin=False
)

for ix, site in site_info.iterrows():
    
    if (site['site_no'] in favorites):
        icon = favorite_icon
        z_index_offset = 100
    else:
        icon = default_icon
        z_index_offset = 0
        
    marker = Marker(
        icon=icon,
        location=(site['dec_lat_va'], site['dec_long_va']),
        draggable=False,
        title=site['station_nm'],
        alt=site['site_no'],
        z_index_offset=z_index_offset
    )
    
    message = HTML()
    message.value = site['station_nm'] + '<br/> USGS: ' + site['site_no']

    popup = Popup(
        location=(site['dec_lat_va'], site['dec_long_va']),
        child=message,
        close_button=False,
        auto_close=False,
        close_on_escape_key=False
    )
    marker.popup = popup

    m.add_layer(marker)

m
# Out:
# Map(center=[-18.0792215, -18.0792215], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_tit…

# %% [markdown]
# ## Get site information and statistics

# %%
gage = '015765195'

gage_info = site_info[site_info['site_no']==gage]

# %%
gage_stats, _ = nwis.get_stats(sites=gage)
gage_stats
# Out:
#      agency_cd    site_no  parameter_cd   ts_id  loc_web_ds  month_nu  day_nu  \
# 0         USGS  015765195            10  170026         NaN         1       1
# 1         USGS  015765195            10  170026         NaN         1       2
# 2         USGS  015765195            10  170026         NaN         1       3
# 3         USGS  015765195            10  170026         NaN         1       4
# 4         USGS  015765195            10  170026         NaN         1       5
# ...        ...        ...           ...     ...         ...       ...     ...
# 1459      USGS  015765195         63680  214327         NaN        12      27
# 1460      USGS  015765195         63680  214327         NaN        12      28
# 1461      USGS  015765195         63680  214327         NaN        12      29
# 1462      USGS  015765195         63680  214327         NaN        12      30
# 1463      USGS  015765195         63680  214327         NaN        12      31
#
#       begin_yr  end_yr  count_nu  ...  mean_va  p05_va  p10_va  p20_va  \
# 0         2013    2022        10  ...      7.4     NaN     3.2     5.8
# 1         2013    2022        10  ...      7.1     NaN     3.4     5.9
# 2         2013    2022        10  ...      6.7     NaN     3.1     4.1
# 3         2013    2022        10  ...      6.7     NaN     3.4     4.3
# 4         2013    2022        10  ...      6.2     NaN     1.9     4.6
# ...        ...     ...       ...  ...      ...     ...     ...     ...
# 1459      2017    2022         6  ...      6.4     NaN     NaN     1.1
# 1460      2017    2022         6  ...     12.0     NaN     NaN     1.3
# 1461      2017    2022         6  ...      4.3     NaN     NaN     1.5
# 1462      2017    2022         5  ...      5.6     NaN     NaN     1.5
# 1463      2017    2022         5  ...      5.6     NaN     NaN     1.1
#
#       p25_va  p50_va  p75_va  p80_va  p90_va  p95_va
# 0        6.2     7.4     8.8     9.3    11.0     NaN
# 1        6.0     6.9     8.3     9.0    10.7     NaN
# 2        5.1     7.2     8.2     8.9     9.3     NaN
# 3        5.5     6.8     8.3     8.6     9.8     NaN
# 4        4.6     6.1     8.0     8.5     9.3     NaN
# ...      ...     ...     ...     ...     ...     ...
# 1459     1.4     4.2    10.0    15.0     NaN     NaN
# 1460     1.4     4.2    28.0    33.0     NaN     NaN
# 1461     2.0     4.2     6.4     7.5     NaN     NaN
# 1462     1.7     4.5    10.0    12.0     NaN     NaN
# 1463     1.5     2.2    11.0    16.0     NaN     NaN
#
# [1464 rows x 24 columns]

# %% [markdown]
# ## Reading our data
#
# Next we will read two parquet files using Pandas. The `read_parquet` function takes a quoted string representing the filesystem path to the file we want to read.
#
# We use parquet here because it has some advantages over a CSV file:
#
# - the filesize is smaller
# - it is a binary format that reads quickly, whereas CSV is text that needs to be parsed
# - parquet preserves the index, including indices of datetime

# %%
start = '1970-01-01'
end = datetime.datetime.today().date()
service = 'iv' # daily value dv, or instantaneous value iv
df = nwis.get_record(sites=gage, service=service, start=start, end=end)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [19], in <cell line: 4>()
#       2 end = datetime.datetime.today().date()
#       3 service = 'iv' # daily value dv, or instantaneous value iv
# ----> 4 df = nwis.get_record(sites=gage, service=service, start=start, end=end)
#
# File ~\anaconda3\lib\site-packages\dataretrieval\nwis.py:576, in get_record(sites, start, end, state, service, *args, **kwargs)
#     573     raise TypeError('Unrecognized service: {}'.format(service))
#     575 if service == 'iv':
# --> 576     df, _ = get_iv(sites=sites, startDT=start, endDT=end, **kwargs)
#     577     return df
#     579 elif service == 'dv':
#
# File ~\anaconda3\lib\site-packages\dataretrieval\nwis.py:430, in get_iv(start, end, **kwargs)
#     428 start = kwargs.pop('startDT', start)
#     429 end = kwargs.pop('endDT', end)
# --> 430 return _iv(startDT=start, endDT=end, **kwargs)
#
# File ~\anaconda3\lib\site-packages\dataretrieval\nwis.py:435, in _iv(**kwargs)
#     433 def _iv(**kwargs):
#     434     response = query_waterservices('iv', format='json', **kwargs)
# --> 435     return _read_json(response.json()), _set_metadata(response, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# </body></html>
# : 0

# %%
df.head()
# Out:
#                            00010 00010_cd    site_no  00060 00060_cd  00065  \
# datetime
# 2022-12-03 21:00:00-05:00    9.6        P  015765195   1.23        P   3.69
#
#                           00065_cd  00095 00095_cd  63680 63680_cd
# datetime
# 2022-12-03 21:00:00-05:00        P  669.0        P    2.6        P

# %% [markdown]
# Looking at `df` we will see it has several other codes. The NWIS codes included here stand for:
# - 00010 : Temperature in degrees celcius
# - 00060 : Discharge
# - 63680 : Turbidity
#
# We can describe them to obtain some summary statistics.

# %%
df.describe()

# %%
df.index

# %% [markdown]
# ## Save as parquet
#
# Saving a DataFrame in Parquet format has some advantages over saving to CSV. Parquet files tend to be smaller on disk and faster to read. Parquet will maintain your data types so you do not need to specify dtypes or parse datetime strings on re-reading the file.

# %%
df.to_parquet('nwis_{}_{}_{}.parquet'.format(gage, start, end), index=True)
